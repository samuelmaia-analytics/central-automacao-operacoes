# %% [markdown]
# # Exploratory Analysis\n\nNotebook inicial para exploracao de volume, SLA e backlog.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/customer_support_tickets.csv')
df.head()
